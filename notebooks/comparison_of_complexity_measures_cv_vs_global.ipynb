# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from src.results.tidy_data import performance_df, extract_complexity_df, calculate_differences
from src.results.statistical_analysis import perform_paired_t_tests
from src.visualization.plots import plot_individual_complexity_differences
import warnings
warnings.filterwarnings('ignore')

# %%
df_complexity = pd.read_parquet('data/results/complexity_data.parquet')
df_differences = pd.read_parquet('data/results/differences_data.parquet')

# %%
df_complexity
# Out:
#        dataset   k      metric method  dataset_complexity  \
# 0          a9a   1  mean_folds    kdn            0.190819
# 1          a9a   1  mean_folds    ddn            0.213374
# 2          a9a   1      global    kdn            0.188784
# 3          a9a   1      global    ddn            0.212416
# 4          a9a   2  mean_folds    kdn            0.201003
# ...        ...  ..         ...    ...                 ...
# 2743  vehicle2   9      global    ddn            0.166891
# 2744  vehicle2  10  mean_folds    kdn            0.089862
# 2745  vehicle2  10  mean_folds    ddn            0.189103
# 2746  vehicle2  10      global    kdn            0.079078
# 2747  vehicle2  10      global    ddn            0.178712
#
#       majority_class_complexity  minority_class_complexity  \
# 0                      0.130744                   0.380213
# 1                      0.146188                   0.425189
# 2                      0.129490                   0.375717
# 3                      0.145419                   0.423633
# 4                      0.138729                   0.397335
# ...                         ...                        ...
# 2743                   0.123822                   0.290963
# 2744                   0.071096                   0.143910
# 2745                   0.137653                   0.337305
# 2746                   0.064650                   0.120642
# 2747                   0.131162                   0.315688
#
#       most_complex_value  least_complex_value
# 0               0.380213             0.130744
# 1               0.425189             0.146188
# 2               0.375717             0.129490
# 3               0.423633             0.145419
# 4               0.397335             0.138729
# ...                  ...                  ...
# 2743            0.290963             0.123822
# 2744            0.143910             0.071096
# 2745            0.337305             0.137653
# 2746            0.120642             0.064650
# 2747            0.315688             0.131162
#
# [2748 rows x 9 columns]

# %%
# Call the function to plot the five independent graphs
plot_individual_complexity_differences(df_differences)

# %%
perform_paired_t_tests(df_differences)
# Out:
# Results for method: ddn
# Comparison: dataset_complexity_global vs dataset_complexity_mean_folds - t-statistic: -7.833, p-value: 0.000
# The difference is highly significant at the 99% confidence level (p < 0.01). There is strong evidence that the two measures are different.
#
# Comparison: majority_class_complexity_global vs majority_class_complexity_mean_folds - t-statistic: -2.531, p-value: 0.012
# The difference is significant at the 95% confidence level (p < 0.05). It is likely that the two measures are different.
#
# Comparison: minority_class_complexity_global vs minority_class_complexity_mean_folds - t-statistic: -9.651, p-value: 0.000
# The difference is highly significant at the 99% confidence level (p < 0.01). There is strong evidence that the two measures are different.
#
# Comparison: most_complex_class_global vs most_complex_class_mean_folds - t-statistic: -9.644, p-value: 0.000
# The difference is highly significant at the 99% confidence level (p < 0.01). There is strong evidence that the two measures are different.
#
# Comparison: least_complex_class_global vs least_complex_class_mean_folds - t-statistic: -2.579, p-value: 0.010
# The difference is significant at the 95% confidence level (p < 0.05). It is likely that the two measures are different.
#
#
# Results for method: kdn
# Comparison: dataset_complexity_global vs dataset_complexity_mean_folds - t-statistic: -12.429, p-value: 0.000
# The difference is highly significant at the 99% confidence level (p < 0.01). There is strong evidence that the two measures are different.
#
# Comparison: majority_class_complexity_global vs majority_class_complexity_mean_folds - t-statistic: -10.369, p-value: 0.000
# The difference is highly significant at the 99% confidence level (p < 0.01). There is strong evidence that the two measures are different.
#
# Comparison: minority_class_complexity_global vs minority_class_complexity_mean_folds - t-statistic: -1.302, p-value: 0.193
# The difference is not statistically significant. There is insufficient evidence to conclude that the two measures are different.
#
# Comparison: most_complex_class_global vs most_complex_class_mean_folds - t-statistic: -1.320, p-value: 0.187
# The difference is not statistically significant. There is insufficient evidence to conclude that the two measures are different.
#
# Comparison: least_complex_class_global vs least_complex_class_mean_folds - t-statistic: -10.206, p-value: 0.000
# The difference is highly significant at the 99% confidence level (p < 0.01). There is strong evidence that the two measures are different.
