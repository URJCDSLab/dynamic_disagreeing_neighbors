# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from src.results.statistical_analysis import calculate_spearman_correlations, summarize_correlations, calculate_statistical_differences, compare_global_vs_mean_folds
from src.visualization.plots import plot_score_differences, plot_line_correlations_new
from src.utils import get_max_correlations, get_top_complexity_levels
import warnings
warnings.filterwarnings('ignore')

# %%
df_complexity = pd.read_parquet('data/results/complexity_data.parquet')
df_performance = pd.read_parquet('data/results/performance_data.parquet')

# %%
# Llamada a la función con los DataFrames correspondientes
correlation_results = calculate_spearman_correlations(df_performance, df_complexity)

# %% [markdown]
# ## Determining the Superior Complexity Estimation: Global vs. Mean Folds Through Correlation with Predictive Success

# %% [markdown]
# ### Accuracy

# %%
score_metric = 'accuracy_score'
correlation_results[score_metric]
# Out:
#         method   k complexity_metric performance_metric  \
# 0   mean_folds   1               kdn     accuracy_score
# 1   mean_folds   1               ddn     accuracy_score
# 2   mean_folds   2               kdn     accuracy_score
# 3   mean_folds   2               ddn     accuracy_score
# 4   mean_folds   3               kdn     accuracy_score
# 5   mean_folds   3               ddn     accuracy_score
# 6   mean_folds   4               kdn     accuracy_score
# 7   mean_folds   4               ddn     accuracy_score
# 8   mean_folds   5               kdn     accuracy_score
# 9   mean_folds   5               ddn     accuracy_score
# 10  mean_folds   6               kdn     accuracy_score
# 11  mean_folds   6               ddn     accuracy_score
# 12  mean_folds   7               kdn     accuracy_score
# 13  mean_folds   7               ddn     accuracy_score
# 14  mean_folds   8               kdn     accuracy_score
# 15  mean_folds   8               ddn     accuracy_score
# ...

# %%
df = correlation_results[score_metric]
# Generate a summary of the correlations
correlation_summary = summarize_correlations(df) 

# Show the summary
correlation_summary
# Out:
#        method complexity_metric  mean_corr_dataset  std_corr_dataset  \
# 0      global               ddn           0.856220          0.022377
# 1      global               kdn           0.879668          0.010014
# 2  mean_folds               ddn           0.843266          0.026231
# 3  mean_folds               kdn           0.873781          0.007804
#
#    mean_corr_majority  std_corr_majority  mean_corr_minority  \
# 0            0.828891           0.023127            0.563442
# 1            0.857414           0.008371            0.526762
# 2            0.818942           0.026709            0.551252
# 3            0.833263           0.005871            0.534560
#
#    std_corr_minority  mean_corr_most_complex  std_corr_most_complex  \
# 0           0.069303                0.559256               0.065428
# 1           0.086317                0.515248               0.090182
# 2           0.081908                0.547907               0.077705
# ...

# %%
compare_global_vs_mean_folds(df)
# Out:
# Overall, method 'Global' outperforms 'Mean Folds' in 84 out of 110 comparisons across all k values and complexity metrics (76.36%).
#      k Complexity Metric  Global Wins  Total Comparisons  Win Percentage
# 0    1               ddn            3                  5             0.6
# 1    1               kdn            3                  5             0.6
# 2    2               ddn            1                  5             0.2
# 3    2               kdn            3                  5             0.6
# 4    3               ddn            5                  5             1.0
# 5    3               kdn            3                  5             0.6
# 6    4               ddn            3                  5             0.6
# 7    4               kdn            3                  5             0.6
# 8    5               ddn            5                  5             1.0
# 9    5               kdn            3                  5             0.6
# ...

# %%
df_max_correlations = get_max_correlations(df)
get_top_complexity_levels(df_max_correlations)
# Out:
#      Complexity Level      Method Complexity Metric   k  Max Correlation
# 0  dataset_complexity      global               ddn   1         0.899414
# 1  dataset_complexity      global               kdn   1         0.895393
# 2  dataset_complexity  mean_folds               ddn   1         0.893418
# 3  dataset_complexity  mean_folds               kdn  11         0.885464

# %%
plot_line_correlations_new(df, score_metric, method_labels={"global": "Global", "mean_folds": "Mean Folds"})
# Out:
# Correlation of  Dataset Complexity with Performance (accuracy_score)
# Correlation of  Majority Class Complexity with Performance (accuracy_score)
# Correlation of  Minority Class Complexity with Performance (accuracy_score)
# Correlation of  Most Complex Class with Performance (accuracy_score)
# Correlation of  Least Complex Class with Performance (accuracy_score)

# %% [markdown]
# ### F1

# %%
score_metric = 'f1_score'
correlation_results[score_metric]
# Out:
#         method   k complexity_metric performance_metric  \
# 0   mean_folds   1               kdn           f1_score
# 1   mean_folds   1               ddn           f1_score
# 2   mean_folds   2               kdn           f1_score
# 3   mean_folds   2               ddn           f1_score
# 4   mean_folds   3               kdn           f1_score
# 5   mean_folds   3               ddn           f1_score
# 6   mean_folds   4               kdn           f1_score
# 7   mean_folds   4               ddn           f1_score
# 8   mean_folds   5               kdn           f1_score
# 9   mean_folds   5               ddn           f1_score
# 10  mean_folds   6               kdn           f1_score
# 11  mean_folds   6               ddn           f1_score
# 12  mean_folds   7               kdn           f1_score
# 13  mean_folds   7               ddn           f1_score
# 14  mean_folds   8               kdn           f1_score
# 15  mean_folds   8               ddn           f1_score
# ...

# %%
df = correlation_results[score_metric]
# Generate a summary of the correlations
correlation_summary = summarize_correlations(df)  

# Show the summary
correlation_summary
# Out:
#        method complexity_metric  mean_corr_dataset  std_corr_dataset  \
# 0      global               ddn           0.151642          0.091481
# 1      global               kdn           0.219449          0.063077
# 2  mean_folds               ddn           0.128988          0.097736
# 3  mean_folds               kdn           0.250805          0.076702
#
#    mean_corr_majority  std_corr_majority  mean_corr_minority  \
# 0            0.156487           0.118469            0.708042
# 1            0.204594           0.078935            0.832301
# 2            0.144813           0.116681            0.678143
# 3            0.267240           0.086673            0.801215
#
#    std_corr_minority  mean_corr_most_complex  std_corr_most_complex  \
# 0           0.083197                0.669225               0.084577
# 1           0.025253                0.797312               0.027273
# 2           0.091961                0.640194               0.092204
# ...

# %%
compare_global_vs_mean_folds(df)
# Out:
# Overall, method 'Global' outperforms 'Mean Folds' in 77 out of 110 comparisons across all k values and complexity metrics (70.00%).
#      k Complexity Metric  Global Wins  Total Comparisons  Win Percentage
# 0    1               ddn            4                  5             0.8
# 1    1               kdn            2                  5             0.4
# 2    2               ddn            5                  5             1.0
# 3    2               kdn            2                  5             0.4
# 4    3               ddn            5                  5             1.0
# 5    3               kdn            2                  5             0.4
# 6    4               ddn            5                  5             1.0
# 7    4               kdn            2                  5             0.4
# 8    5               ddn            5                  5             1.0
# 9    5               kdn            2                  5             0.4
# ...

# %%
df_max_correlations = get_max_correlations(df)
get_top_complexity_levels(df_max_correlations)
# Out:
#             Complexity Level      Method Complexity Metric  k  Max Correlation
# 0  minority_class_complexity      global               ddn  2         0.821187
# 1  minority_class_complexity      global               kdn  8         0.857455
# 2  minority_class_complexity  mean_folds               ddn  1         0.807869
# 3  minority_class_complexity  mean_folds               kdn  7         0.822948

# %%
plot_line_correlations_new(df, score_metric, method_labels={"global": "Global", "mean_folds": "Mean Folds"})
# Out:
# Correlation of  Dataset Complexity with Performance (f1_score)
# Correlation of  Majority Class Complexity with Performance (f1_score)
# Correlation of  Minority Class Complexity with Performance (f1_score)
# Correlation of  Most Complex Class with Performance (f1_score)
# Correlation of  Least Complex Class with Performance (f1_score)

# %% [markdown]
# ### GPS

# %%
score_metric = 'gps_score'
correlation_results['gps_score']
# Out:
#         method   k complexity_metric performance_metric  \
# 0   mean_folds   1               kdn          gps_score
# 1   mean_folds   1               ddn          gps_score
# 2   mean_folds   2               kdn          gps_score
# 3   mean_folds   2               ddn          gps_score
# 4   mean_folds   3               kdn          gps_score
# 5   mean_folds   3               ddn          gps_score
# 6   mean_folds   4               kdn          gps_score
# 7   mean_folds   4               ddn          gps_score
# 8   mean_folds   5               kdn          gps_score
# 9   mean_folds   5               ddn          gps_score
# 10  mean_folds   6               kdn          gps_score
# 11  mean_folds   6               ddn          gps_score
# 12  mean_folds   7               kdn          gps_score
# 13  mean_folds   7               ddn          gps_score
# 14  mean_folds   8               kdn          gps_score
# 15  mean_folds   8               ddn          gps_score
# ...

# %%
df = correlation_results[score_metric]
# Generate a summary of the correlations
correlation_summary = summarize_correlations(df) 

# Show the summary
correlation_summary
# Out:
#        method complexity_metric  mean_corr_dataset  std_corr_dataset  \
# 0      global               ddn           0.227460          0.092528
# 1      global               kdn           0.294706          0.065337
# 2  mean_folds               ddn           0.204359          0.099598
# 3  mean_folds               kdn           0.327908          0.079789
#
#    mean_corr_majority  std_corr_majority  mean_corr_minority  \
# 0            0.243983           0.122496            0.687733
# 1            0.288082           0.084041            0.819811
# 2            0.232054           0.122267            0.656246
# 3            0.351411           0.092512            0.790044
#
#    std_corr_minority  mean_corr_most_complex  std_corr_most_complex  \
# 0           0.091339                0.650443               0.090618
# 1           0.024992                0.784768               0.027041
# 2           0.101480                0.619787               0.099684
# ...

# %%
compare_global_vs_mean_folds(df)
# Out:
# Overall, method 'Global' outperforms 'Mean Folds' in 76 out of 110 comparisons across all k values and complexity metrics (69.09%).
#      k Complexity Metric  Global Wins  Total Comparisons  Win Percentage
# 0    1               ddn            3                  5             0.6
# 1    1               kdn            2                  5             0.4
# 2    2               ddn            5                  5             1.0
# 3    2               kdn            2                  5             0.4
# 4    3               ddn            5                  5             1.0
# 5    3               kdn            2                  5             0.4
# 6    4               ddn            5                  5             1.0
# 7    4               kdn            2                  5             0.4
# 8    5               ddn            5                  5             1.0
# 9    5               kdn            2                  5             0.4
# ...

# %%
df_max_correlations = get_max_correlations(df)
get_top_complexity_levels(df_max_correlations)
# Out:
#             Complexity Level      Method Complexity Metric  k  Max Correlation
# 0  minority_class_complexity      global               ddn  1         0.813748
# 1  minority_class_complexity      global               kdn  8         0.841670
# 2  minority_class_complexity  mean_folds               ddn  1         0.800044
# 3  minority_class_complexity  mean_folds               kdn  6         0.812544

# %%
plot_line_correlations_new(df, score_metric, method_labels={"global": "Global", "mean_folds": "Mean Folds"})
# Out:
# Correlation of  Dataset Complexity with Performance (gps_score)
# Correlation of  Majority Class Complexity with Performance (gps_score)
# Correlation of  Minority Class Complexity with Performance (gps_score)
# Correlation of  Most Complex Class with Performance (gps_score)
# Correlation of  Least Complex Class with Performance (gps_score)

# %% [markdown]
# ### MCC

# %%
score_metric = 'scaled_mcc_score'
correlation_results[score_metric]
# Out:
#         method   k complexity_metric performance_metric  \
# 0   mean_folds   1               kdn   scaled_mcc_score
# 1   mean_folds   1               ddn   scaled_mcc_score
# 2   mean_folds   2               kdn   scaled_mcc_score
# 3   mean_folds   2               ddn   scaled_mcc_score
# 4   mean_folds   3               kdn   scaled_mcc_score
# 5   mean_folds   3               ddn   scaled_mcc_score
# 6   mean_folds   4               kdn   scaled_mcc_score
# 7   mean_folds   4               ddn   scaled_mcc_score
# 8   mean_folds   5               kdn   scaled_mcc_score
# 9   mean_folds   5               ddn   scaled_mcc_score
# 10  mean_folds   6               kdn   scaled_mcc_score
# 11  mean_folds   6               ddn   scaled_mcc_score
# 12  mean_folds   7               kdn   scaled_mcc_score
# 13  mean_folds   7               ddn   scaled_mcc_score
# 14  mean_folds   8               kdn   scaled_mcc_score
# 15  mean_folds   8               ddn   scaled_mcc_score
# ...

# %%
df = correlation_results[score_metric]
# Generate a summary of the correlations
correlation_summary = summarize_correlations(df)  
# Show the summary
correlation_summary
# Out:
#        method complexity_metric  mean_corr_dataset  std_corr_dataset  \
# 0      global               ddn           0.316495          0.079857
# 1      global               kdn           0.379746          0.052816
# 2  mean_folds               ddn           0.294334          0.087167
# 3  mean_folds               kdn           0.411880          0.066482
#
#    mean_corr_majority  std_corr_majority  mean_corr_minority  \
# 0            0.330450           0.107516            0.687819
# 1            0.371223           0.072220            0.812641
# 2            0.318977           0.108072            0.657076
# 3            0.433857           0.081394            0.785653
#
#    std_corr_minority  mean_corr_most_complex  std_corr_most_complex  \
# 0           0.094398                0.652464               0.091442
# 1           0.021619                0.777547               0.023374
# 2           0.105097                0.622475               0.101230
# ...

# %%
compare_global_vs_mean_folds(df)
# Out:
# Overall, method 'Global' outperforms 'Mean Folds' in 76 out of 110 comparisons across all k values and complexity metrics (69.09%).
#      k Complexity Metric  Global Wins  Total Comparisons  Win Percentage
# 0    1               ddn            3                  5             0.6
# 1    1               kdn            2                  5             0.4
# 2    2               ddn            5                  5             1.0
# 3    2               kdn            2                  5             0.4
# 4    3               ddn            5                  5             1.0
# 5    3               kdn            2                  5             0.4
# 6    4               ddn            5                  5             1.0
# 7    4               kdn            2                  5             0.4
# 8    5               ddn            5                  5             1.0
# 9    5               kdn            2                  5             0.4
# ...

# %%
df_max_correlations = get_max_correlations(df)
get_top_complexity_levels(df_max_correlations)
# Out:
#             Complexity Level      Method Complexity Metric  k  Max Correlation
# 0  minority_class_complexity      global               ddn  1         0.820307
# 1  minority_class_complexity      global               kdn  3         0.832563
# 2  minority_class_complexity  mean_folds               ddn  1         0.807344
# 3  minority_class_complexity  mean_folds               kdn  6         0.805464

# %%
plot_line_correlations_new(df, score_metric, method_labels={"global": "Global", "mean_folds": "Mean Folds"})
# Out:
# Correlation of  Dataset Complexity with Performance (scaled_mcc_score)
# Correlation of  Majority Class Complexity with Performance (scaled_mcc_score)
# Correlation of  Minority Class Complexity with Performance (scaled_mcc_score)
# Correlation of  Most Complex Class with Performance (scaled_mcc_score)
# Correlation of  Least Complex Class with Performance (scaled_mcc_score)

# %% [markdown]
# ## Analysis of Performance Differences Relative to Complexity Measures Across k Values

# %%
df_score_differences = pd.read_parquet('data/results/score_differences_data.parquet')

# %%
df_score_differences
# Out:
#        dataset          metric_x     score  score_sd   k metric_y  \
# 0          a9a    accuracy_score  0.850035  0.003225   1      kdn
# 1          a9a    accuracy_score  0.850035  0.003225   1      ddn
# 2          a9a    accuracy_score  0.850035  0.003225   2      kdn
# 3          a9a    accuracy_score  0.850035  0.003225   2      ddn
# 4          a9a    accuracy_score  0.850035  0.003225   3      kdn
# ...        ...               ...       ...       ...  ..      ...
# 5491  vehicle2  scaled_mcc_score  0.987671  0.007849   8      ddn
# 5492  vehicle2  scaled_mcc_score  0.987671  0.007849   9      kdn
# 5493  vehicle2  scaled_mcc_score  0.987671  0.007849   9      ddn
# 5494  vehicle2  scaled_mcc_score  0.987671  0.007849  10      kdn
# 5495  vehicle2  scaled_mcc_score  0.987671  0.007849  10      ddn
#
#       dataset_complexity  minority_class_complexity  most_complex_class  \
# 0               0.188784                   0.375717            0.375717
# ...

# %% [markdown]
# ### Accuracy

# %%
plot_score_differences(df_score_differences, 'accuracy_score')

# %%
statistical_results, explanation_text = calculate_statistical_differences(df_score_differences, 'accuracy_score')
display(statistical_results)
print(explanation_text)
# Out:
#   method performance_metric  k                  test_used  test_statistic  \
# 0    kdn     accuracy_score  1  Wilcoxon signed-rank test             0.0
# 1    ddn     accuracy_score  1  Wilcoxon signed-rank test             0.0
#
#     p_value  normality_p_value normality_test
# 0  0.179712       6.153847e-18   Shapiro-Wilk
# 1  0.179712       6.155228e-18   Shapiro-Wilk
# For method kdn using Wilcoxon signed-rank test: There is no statistically significant difference between the two measures. Test statistic: 0.000, p-value: 0.180.
# For method ddn using Wilcoxon signed-rank test: There is no statistically significant difference between the two measures. Test statistic: 0.000, p-value: 0.180.

# %% [markdown]
# ### F1

# %%
plot_score_differences(df_score_differences, 'f1_score')

# %%
statistical_results, explanation_text = calculate_statistical_differences(df_score_differences, 'f1_score')
display(statistical_results)
print(explanation_text)
# Out:
#   method performance_metric  k                  test_used  test_statistic  \
# 0    kdn           f1_score  1  Wilcoxon signed-rank test             0.0
# 1    ddn           f1_score  1  Wilcoxon signed-rank test             0.0
#
#     p_value  normality_p_value normality_test
# 0  0.179712       6.153847e-18   Shapiro-Wilk
# 1  0.179712       6.155228e-18   Shapiro-Wilk
# For method kdn using Wilcoxon signed-rank test: There is no statistically significant difference between the two measures. Test statistic: 0.000, p-value: 0.180.
# For method ddn using Wilcoxon signed-rank test: There is no statistically significant difference between the two measures. Test statistic: 0.000, p-value: 0.180.

# %% [markdown]
# ### GPS

# %%
plot_score_differences(df_score_differences, 'gps_score')

# %%
statistical_results, explanation_text = calculate_statistical_differences(df_score_differences, 'gps_score')
display(statistical_results)
print(explanation_text)
# Out:
#   method performance_metric  k                  test_used  test_statistic  \
# 0    kdn          gps_score  1  Wilcoxon signed-rank test             0.0
# 1    ddn          gps_score  1  Wilcoxon signed-rank test             0.0
#
#     p_value  normality_p_value normality_test
# 0  0.179712       6.153847e-18   Shapiro-Wilk
# 1  0.179712       6.155228e-18   Shapiro-Wilk
# For method kdn using Wilcoxon signed-rank test: There is no statistically significant difference between the two measures. Test statistic: 0.000, p-value: 0.180.
# For method ddn using Wilcoxon signed-rank test: There is no statistically significant difference between the two measures. Test statistic: 0.000, p-value: 0.180.

# %% [markdown]
# ### MCC

# %%
plot_score_differences(df_score_differences, 'scaled_mcc_score')

# %%
statistical_results, explanation_text = calculate_statistical_differences(df_score_differences, 'scaled_mcc_score')
display(statistical_results)
print(explanation_text)
# Out:
#   method performance_metric  k                  test_used  test_statistic  \
# 0    kdn   scaled_mcc_score  1  Wilcoxon signed-rank test             0.0
# 1    ddn   scaled_mcc_score  1  Wilcoxon signed-rank test             0.0
#
#     p_value  normality_p_value normality_test
# 0  0.179712       6.153847e-18   Shapiro-Wilk
# 1  0.179712       6.155228e-18   Shapiro-Wilk
# For method kdn using Wilcoxon signed-rank test: There is no statistically significant difference between the two measures. Test statistic: 0.000, p-value: 0.180.
# For method ddn using Wilcoxon signed-rank test: There is no statistically significant difference between the two measures. Test statistic: 0.000, p-value: 0.180.
